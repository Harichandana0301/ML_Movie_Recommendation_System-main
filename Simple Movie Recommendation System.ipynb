# %%
import pandas as pd
import numpy as np

# %%
#Import
merged_df = pd.read_csv('final_merged_movies.csv')
merged_df.head(2)
# Out:
#                                    Movie_Name  Rating_Score  \
# 0  Star Wars: Episode VII - The Force Awakens           7.8
# 1                           Avengers: Endgame           8.4
#
#                  Movie_Genre  \
# 0  Action, Adventure, Sci-Fi
# 1   Action, Adventure, Drama
#
#                                                 Cast    Gross_USA  \
# 0  J.J. Abrams,  Daisy Ridley, John Boyega, Oscar...  936662225.0
# 1  Anthony Russo, Joe Russo,  Robert Downey Jr., ...  858373000.0
#
#                                             keywords  \
# 0                     android,spacecraft,space opera
# 1  space travel,time travel,time machine,sequel,s...
#
#                                             overview  Total_Votes
# 0  Thirty years after defeating the Galactic Empi...     937561.0
# 1  After the devastating events of Avengers: Infi...    1147483.0

# %%
#Weighted Average Calculation
merged_df['Rating_Score'] = merged_df['Rating_Score'].astype(float)
merged_df['Total_Votes'] = merged_df['Total_Votes'].astype(float)
merged_df['weighted_rating'] = ((merged_df['Rating_Score'] * merged_df['Total_Votes']) / (merged_df['Total_Votes'].sum()))
merged_df.head()
# Out:
#                                    Movie_Name  Rating_Score  \
# 0  Star Wars: Episode VII - The Force Awakens           7.8
# 1                           Avengers: Endgame           8.4
# 2                     Spider-Man: No Way Home           8.2
# 3                              Jurassic World           6.9
# 4     Star Wars: Episode VIII - The Last Jedi           6.9
#
#                   Movie_Genre  \
# 0   Action, Adventure, Sci-Fi
# 1    Action, Adventure, Drama
# 2  Action, Adventure, Fantasy
# 3   Action, Adventure, Sci-Fi
# 4  Action, Adventure, Fantasy
#
#                                                 Cast    Gross_USA  \
# 0  J.J. Abrams,  Daisy Ridley, John Boyega, Oscar...  936662225.0
# 1  Anthony Russo, Joe Russo,  Robert Downey Jr., ...  858373000.0
# 2  Jon Watts,  Tom Holland, Zendaya, Benedict Cum...  804747988.0
# 3  Colin Trevorrow,  Chris Pratt, Bryce Dallas Ho...  652270625.0
# 4  Rian Johnson,  Daisy Ridley, John Boyega, Mark...  620181382.0
#
# ...

# %%
#Sort the movies by Gross Income and Weighted Average of Movie Rating
def recommend_movies_by_genre(genre, top_n=10):
    movies_by_genre = merged_df[merged_df['Movie_Genre'].str.contains(genre)]
    movie_info = movies_by_genre.sort_values(['Gross_USA', 'weighted_rating'], ascending=False).head(top_n)
    return movie_info

# %%
recommend_movies_by_genre('Romance')
# Out:
#                  Movie_Name  Rating_Score               Movie_Genre  \
# 88     Fifty Shades of Grey           4.2  Drama, Romance, Thriller
# 131  The Fault in Our Stars           7.7            Drama, Romance
# 139     Fifty Shades Darker           4.6  Drama, Romance, Thriller
# 147              Trainwreck           6.2    Comedy, Drama, Romance
# 151            Little Women           7.8            Drama, Romance
# 172              Passengers           7.0    Drama, Romance, Sci-Fi
# 174           Downton Abbey           7.4            Drama, Romance
# 204         The Other Woman           6.0           Comedy, Romance
# 244               Book Club           6.1    Comedy, Drama, Romance
# 261      The Shape of Water           7.3   Drama, Fantasy, Romance
#
#                                                   Cast    Gross_USA  \
# 88   Sam Taylor-Johnson,  Dakota Johnson, Jamie Dor...  166167230.0
# 131  Josh Boone,  Shailene Woodley, Ansel Elgort, N...  124872350.0
# ...

# %%
recommend_movies_by_genre('Action')
# Out:
#                                     Movie_Name  Rating_Score  \
# 0   Star Wars: Episode VII - The Force Awakens           7.8
# 1                            Avengers: Endgame           8.4
# 2                      Spider-Man: No Way Home           8.2
# 3                               Jurassic World           6.9
# 4      Star Wars: Episode VIII - The Last Jedi           6.9
# 6                 Rogue One: A Star Wars Story           7.8
# 7             Star Wars: The Rise Of Skywalker           6.5
# 11                     Avengers: Age of Ultron           7.3
# 13                              Captain Marvel           6.8
# 14                                Wonder Woman           7.4
#
#                    Movie_Genre  \
# 0    Action, Adventure, Sci-Fi
# 1     Action, Adventure, Drama
# 2   Action, Adventure, Fantasy
# 3    Action, Adventure, Sci-Fi
# 4   Action, Adventure, Fantasy
# 6    Action, Adventure, Sci-Fi
# 7   Action, Adventure, Fantasy
# 11   Action, Adventure, Sci-Fi
# ...

# %%
recommend_movies_by_genre('Sci-Fi')
# Out:
#                                     Movie_Name  Rating_Score  \
# 0   Star Wars: Episode VII - The Force Awakens           7.8
# 3                               Jurassic World           6.9
# 6                 Rogue One: A Star Wars Story           7.8
# 11                     Avengers: Age of Ultron           7.3
# 13                              Captain Marvel           6.8
# 15                  Captain America: Civil War           7.8
# 27       The Hunger Games: Mockingjay - Part 1           6.6
# 30                      Spider-Man: Homecoming           7.4
# 32          Batman v Superman: Dawn of Justice           6.4
# 37       The Hunger Games: Mockingjay - Part 2           6.5
#
#                   Movie_Genre  \
# 0   Action, Adventure, Sci-Fi
# 3   Action, Adventure, Sci-Fi
# 6   Action, Adventure, Sci-Fi
# 11  Action, Adventure, Sci-Fi
# 13  Action, Adventure, Sci-Fi
# 15             Action, Sci-Fi
# 27  Action, Adventure, Sci-Fi
# 30  Action, Adventure, Sci-Fi
# ...

# %%
recommend_movies_by_genre('Mystery')
# Out:
#                        Movie_Name  Rating_Score                 Movie_Genre  \
# 75                        Get Out           7.7   Horror, Mystery, Thriller
# 77                             Us           6.8   Horror, Mystery, Thriller
# 87                      Gone Girl           8.1    Drama, Mystery, Thriller
# 107                     Divergent           6.6  Action, Adventure, Mystery
# 160  Murder on the Orient Express           6.5       Crime, Drama, Mystery
# 161               The Conjuring 2           7.3   Horror, Mystery, Thriller
# 162               The Maze Runner           6.8     Action, Mystery, Sci-Fi
# 163           Annabelle: Creation           6.5   Horror, Mystery, Thriller
# 167                       Arrival           7.9      Drama, Mystery, Sci-Fi
# 179                      Non-Stop           6.9   Action, Mystery, Thriller
#
#                                                   Cast    Gross_USA  \
# ...

# %%
recommend_movies_by_genre('Crime')
# Out:
#                             Movie_Name  Rating_Score              Movie_Genre  \
# 24                           Furious 7           7.1  Action, Crime, Thriller
# 29                               Joker           8.4   Crime, Drama, Thriller
# 52             The Fate of the Furious           6.6  Action, Crime, Thriller
# 59                   Bad Boys for Life           6.5    Action, Comedy, Crime
# 65                      22 Jump Street           7.0    Action, Comedy, Crime
# 81                   F9: The Fast Saga           5.2  Action, Crime, Thriller
# 83   John Wick: Chapter 3 - Parabellum           7.4  Action, Crime, Thriller
# 89                          Knives Out           7.9     Comedy, Crime, Drama
# 117                         Ride Along           6.1    Action, Comedy, Crime
# 127               Central Intelligence           6.3    Action, Comedy, Crime
#
#                                                   Cast    Gross_USA  \
# ...

# %%
recommend_movies_by_genre('Drama')
# Out:
#                         Movie_Name  Rating_Score                  Movie_Genre  \
# 1                Avengers: Endgame           8.4     Action, Adventure, Drama
# 5                    The Lion King           6.8  Animation, Adventure, Drama
# 20                 The Jungle Book           7.4     Adventure, Drama, Family
# 25                 American Sniper           7.3     Action, Biography, Drama
# 29                           Joker           8.4       Crime, Drama, Thriller
# 50                     The Martian           8.0     Adventure, Drama, Sci-Fi
# 51                           Logan           8.1        Action, Drama, Sci-Fi
# 56                  It Chapter Two           6.5       Drama, Fantasy, Horror
# 58  Dawn of the Planet of the Apes           7.6     Action, Adventure, Drama
# 61                      Cinderella           6.9     Adventure, Drama, Family
#
#                                                  Cast    Gross_USA  \
# ...

# %%
recommend_movies_by_genre('Thriller')
# Out:
#                                Movie_Name  Rating_Score  \
# 24                              Furious 7           7.1
# 29                                  Joker           8.4
# 52                The Fate of the Furious           6.6
# 55            Venom: Let There Be Carnage           5.9
# 63                                Spectre           6.8
# 64     Mission: Impossible - Rogue Nation           7.4
# 75                                Get Out           7.7
# 77                                     Us           6.8
# 80  Fast & Furious Presents: Hobbs & Shaw           6.5
# 81                      F9: The Fast Saga           5.2
#
#                     Movie_Genre  \
# 24      Action, Crime, Thriller
# 29       Crime, Drama, Thriller
# 52      Action, Crime, Thriller
# 55     Action, Sci-Fi, Thriller
# 63  Action, Adventure, Thriller
# 64  Action, Adventure, Thriller
# 75    Horror, Mystery, Thriller
# 77    Horror, Mystery, Thriller
# 80  Action, Adventure, Thriller
# ...
